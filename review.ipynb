# %%
import pandas as pd

# %%
path1 = "us_disaster_declarations.csv"

# %%
data1 = pd.read_csv(path1)
data1
# Out:
#       fema_declaration_string  disaster_number state declaration_type  \
# 0                     DR-1-GA                1    GA               DR
# 1                     DR-2-TX                2    TX               DR
# 2                     DR-3-LA                3    LA               DR
# 3                     DR-4-MI                4    MI               DR
# 4                     DR-5-MT                5    MT               DR
# ...                       ...              ...   ...              ...
# 63696              EM-3586-NC             3586    NC               EM
# 63697              EM-3586-NC             3586    NC               EM
# 63698              DR-4676-IL             4676    IL               DR
# 63699              FM-5456-WA             5456    WA               FM
# 63700              FM-5456-WA             5456    WA               FM
#
#            declaration_date  fy_declared incident_type  \
# 0      1953-05-02T00:00:00Z         1953       Tornado
# ...

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 63701 entries, 0 to 63700
# Data columns (total 23 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   fema_declaration_string     63701 non-null  object
#  1   disaster_number             63701 non-null  int64
#  2   state                       63701 non-null  object
#  3   declaration_type            63701 non-null  object
#  4   declaration_date            63701 non-null  object
#  5   fy_declared                 63701 non-null  int64
#  6   incident_type               63701 non-null  object
#  7   declaration_title           63701 non-null  object
#  8   ih_program_declared         63701 non-null  int64
#  9   ia_program_declared         63701 non-null  int64
#  10  pa_program_declared         63701 non-null  int64
#  11  hm_program_declared         63701 non-null  int64
#  12  incident_begin_date         63701 non-null  object
# ...

# %%
data1.isnull().sum()
# Out:
# fema_declaration_string           0
# disaster_number                   0
# state                             0
# declaration_type                  0
# declaration_date                  0
# fy_declared                       0
# incident_type                     0
# declaration_title                 0
# ih_program_declared               0
# ia_program_declared               0
# pa_program_declared               0
# hm_program_declared               0
# incident_begin_date               0
# incident_end_date              8667
# disaster_closeout_date        15237
# fips                              0
# place_code                        0
# designated_area                   0
# declaration_request_number        0
# last_ia_filing_date           46127
# hash                              0
# id                                0
# last_refresh                      0
# dtype: int64

# %%
data1.drop(['last_ia_filing_date'],axis=1, inplace=True)

# %%
data1.incident_type.unique()
# Out:
# array(['Tornado', 'Flood', 'Fire', 'Other', 'Earthquake', 'Hurricane',
#        'Volcano', 'Severe Storm(s)', 'Toxic Substances', 'Typhoon',
#        'Drought', 'Dam/Levee Break', 'Snow', 'Severe Ice Storm',
#        'Freezing', 'Coastal Storm', 'Fishing Losses', 'Mud/Landslide',
#        'Human Cause', 'Terrorist', 'Tsunami', 'Chemical', 'Biological'],
#       dtype=object)

# %%
data1.incident_type.nunique()
# Out:
# 23

# %%
data1.incident_type.value_counts()
# Out:
# Severe Storm(s)     17438
# Hurricane           12946
# Flood               10563
# Biological           7857
# Snow                 3695
# Fire                 3614
# Severe Ice Storm     2942
# Tornado              1569
# Drought              1292
# Coastal Storm         638
# Other                 307
# Freezing              301
# Earthquake            227
# Typhoon               130
# Volcano                51
# Fishing Losses         42
# Mud/Landslide          37
# Dam/Levee Break        13
# Toxic Substances        9
# Tsunami                 9
# Chemical                9
# Human Cause             7
# Terrorist               5
# Name: incident_type, dtype: int64

# %%
remove= ['Human Cause','Terrorist','Chemical','Biological','Fishing Losses','Dam/Levee Break','Toxic Substances','Other']

# %%
remove2= []

# %%
data2 = data1[data1.incident_type.isin(remove) == False]
data2
# Out:
#       fema_declaration_string  disaster_number state declaration_type  \
# 0                     DR-1-GA                1    GA               DR
# 1                     DR-2-TX                2    TX               DR
# 2                     DR-3-LA                3    LA               DR
# 3                     DR-4-MI                4    MI               DR
# 4                     DR-5-MT                5    MT               DR
# ...                       ...              ...   ...              ...
# 63696              EM-3586-NC             3586    NC               EM
# 63697              EM-3586-NC             3586    NC               EM
# 63698              DR-4676-IL             4676    IL               DR
# 63699              FM-5456-WA             5456    WA               FM
# 63700              FM-5456-WA             5456    WA               FM
#
#            declaration_date  fy_declared incident_type  \
# 0      1953-05-02T00:00:00Z         1953       Tornado
# ...

# %%
a= data2.state.unique()
a
# Out:
# array(['GA', 'TX', 'LA', 'MI', 'MT', 'IA', 'MA', 'NH', 'FL', 'MS', 'CA',
#        'NV', 'SD', 'WV', 'RI', 'ME', 'CT', 'NY', 'NM', 'NC', 'SC', 'IN',
#        'HI', 'CO', 'KS', 'OK', 'NJ', 'PA', 'OR', 'WA', 'ID', 'PR', 'KY',
#        'VA', 'MO', 'AR', 'ND', 'IL', 'MN', 'OH', 'NE', 'AL', 'MD', 'DE',
#        'GU', 'TN', 'FM', 'WY', 'VT', 'AK', 'VI', 'WI', 'AS', 'AZ', 'MP',
#        'UT', 'MH', 'DC', 'PW'], dtype=object)

# %%
path2 = "States - Sheet1.csv"
state_data = pd.read_csv(path2)
state_data
# Out:
#                    State Standard state_mergekey
# 0                Alabama     Ala.             AL
# 1                 Alaska   Alaska             AK
# 2                Arizona    Ariz.             AZ
# 3               Arkansas     Ark.             AR
# 4             California   Calif.             CA
# 5             Canal Zone     C.Z.             CZ
# 6               Colorado    Colo.             CO
# 7            Connecticut    Conn.             CT
# 8               Delaware     Del.             DE
# 9   District of Columbia     D.C.             DC
# 10               Florida     Fla.             FL
# 11               Georgia      Ga.             GA
# 12                  Guam     Guam             GU
# 13                Hawaii   Hawaii             HI
# 14                 Idaho    Idaho             ID
# 15              Illinois     Ill.             IL
# 16               Indiana     Ind.             IN
# 17                  Iowa     Iowa             IA
# ...

# %%
data2["state"] = data2.state.replace({"DC","MD"})
data3 = pd.merge(left=data2,right=state_data,left_on="state",right_on="state_mergekey",how="left")
data3.declaration_date = pd.to_datetime(data3.declaration_date)
data3
# Out:
# C:\Users\MANIDEDEEPYA\AppData\Local\Temp\ipykernel_13572\2147692777.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data2["state"] = data2.state.replace({"DC","MD"})
#       fema_declaration_string  disaster_number state declaration_type  \
# 0                     DR-1-GA                1    GA               DR
# 1                     DR-2-TX                2    TX               DR
# 2                     DR-3-LA                3    LA               DR
# 3                     DR-4-MI                4    MI               DR
# 4                     DR-5-MT                5    MT               DR
# ...                       ...              ...   ...              ...
# ...

# %%
a= data3.state_mergekey.unique()
a
# Out:
# array(['GA', 'TX', 'LA', 'MI', 'MT', 'IA', 'MA', 'NH', 'FL', 'MS', 'CA',
#        'NV', 'SD', 'WV', 'RI', 'ME', 'CT', 'NY', 'NM', 'NC', 'SC', 'IN',
#        'HI', 'CO', 'KS', 'OK', 'NJ', 'PA', 'OR', 'WA', 'ID', 'PR', 'KY',
#        'VA', 'MO', 'AR', 'ND', 'IL', 'MN', 'OH', 'NE', 'AL', 'MD', 'DE',
#        'GU', 'TN', nan, 'WY', 'VT', 'AK', 'VI', 'WI', 'AZ', 'UT', 'DC'],
#       dtype=object)

# %%
b= data3.state.unique()
b
# Out:
# array(['GA', 'TX', 'LA', 'MI', 'MT', 'IA', 'MA', 'NH', 'FL', 'MS', 'CA',
#        'NV', 'SD', 'WV', 'RI', 'ME', 'CT', 'NY', 'NM', 'NC', 'SC', 'IN',
#        'HI', 'CO', 'KS', 'OK', 'NJ', 'PA', 'OR', 'WA', 'ID', 'PR', 'KY',
#        'VA', 'MO', 'AR', 'ND', 'IL', 'MN', 'OH', 'NE', 'AL', 'MD', 'DE',
#        'GU', 'TN', 'FM', 'WY', 'VT', 'AK', 'VI', 'WI', 'AS', 'AZ', 'MP',
#        'UT', 'MH', 'DC', 'PW'], dtype=object)

# %%
remove2= ['FM','AS','MP','MH','PW']
data4 = data3[data3.state.isin(remove2) == False]
data4
# Out:
#       fema_declaration_string  disaster_number state declaration_type  \
# 0                     DR-1-GA                1    GA               DR
# 1                     DR-2-TX                2    TX               DR
# 2                     DR-3-LA                3    LA               DR
# 3                     DR-4-MI                4    MI               DR
# 4                     DR-5-MT                5    MT               DR
# ...                       ...              ...   ...              ...
# 55447              EM-3586-NC             3586    NC               EM
# 55448              EM-3586-NC             3586    NC               EM
# 55449              DR-4676-IL             4676    IL               DR
# 55450              FM-5456-WA             5456    WA               FM
# 55451              FM-5456-WA             5456    WA               FM
#
#                declaration_date  fy_declared incident_type  \
# 0     1953-05-02 00:00:00+00:00         1953       Tornado
# ...

# %%
c= data4.state.unique()
c
# Out:
# array(['GA', 'TX', 'LA', 'MI', 'MT', 'IA', 'MA', 'NH', 'FL', 'MS', 'CA',
#        'NV', 'SD', 'WV', 'RI', 'ME', 'CT', 'NY', 'NM', 'NC', 'SC', 'IN',
#        'HI', 'CO', 'KS', 'OK', 'NJ', 'PA', 'OR', 'WA', 'ID', 'PR', 'KY',
#        'VA', 'MO', 'AR', 'ND', 'IL', 'MN', 'OH', 'NE', 'AL', 'MD', 'DE',
#        'GU', 'TN', 'WY', 'VT', 'AK', 'VI', 'WI', 'AZ', 'UT', 'DC'],
#       dtype=object)

# %%
d= data4.state_mergekey.unique()
d
# Out:
# array(['GA', 'TX', 'LA', 'MI', 'MT', 'IA', 'MA', 'NH', 'FL', 'MS', 'CA',
#        'NV', 'SD', 'WV', 'RI', 'ME', 'CT', 'NY', 'NM', 'NC', 'SC', 'IN',
#        'HI', 'CO', 'KS', 'OK', 'NJ', 'PA', 'OR', 'WA', 'ID', 'PR', 'KY',
#        'VA', 'MO', 'AR', 'ND', 'IL', 'MN', 'OH', 'NE', 'AL', 'MD', 'DE',
#        'GU', 'TN', 'WY', 'VT', 'AK', 'VI', 'WI', 'AZ', 'UT', 'DC'],
#       dtype=object)

# %%
data4.isnull().sum()
# Out:
# fema_declaration_string           0
# disaster_number                   0
# state                             0
# declaration_type                  0
# declaration_date                  0
# fy_declared                       0
# incident_type                     0
# declaration_title                 0
# ih_program_declared               0
# ia_program_declared               0
# pa_program_declared               0
# hm_program_declared               0
# incident_begin_date               0
# incident_end_date               808
# disaster_closeout_date        10711
# fips                              0
# place_code                        0
# designated_area                   0
# declaration_request_number        0
# hash                              0
# id                                0
# last_refresh                      0
# State                             0
# Standard                          0
# state_mergekey                    0
# declaration_date_up               0
# ...

# %%
time = data3['declaration_date'].tolist()
time
# Out:
# [Timestamp('1953-05-02 00:00:00+0000', tz='UTC'),
#  Timestamp('1953-05-15 00:00:00+0000', tz='UTC'),
#  Timestamp('1953-05-29 00:00:00+0000', tz='UTC'),
#  Timestamp('1953-06-02 00:00:00+0000', tz='UTC'),
#  Timestamp('1953-06-06 00:00:00+0000', tz='UTC'),
#  Timestamp('1953-06-09 00:00:00+0000', tz='UTC'),
#  Timestamp('1953-06-11 00:00:00+0000', tz='UTC'),
#  Timestamp('1953-06-11 00:00:00+0000', tz='UTC'),
#  Timestamp('1953-06-19 00:00:00+0000', tz='UTC'),
#  Timestamp('1953-07-02 00:00:00+0000', tz='UTC'),
#  Timestamp('1953-10-22 00:00:00+0000', tz='UTC'),
#  Timestamp('1953-12-06 00:00:00+0000', tz='UTC'),
#  Timestamp('1954-02-05 00:00:00+0000', tz='UTC'),
#  Timestamp('1954-03-17 00:00:00+0000', tz='UTC'),
#  Timestamp('1954-06-23 00:00:00+0000', tz='UTC'),
#  Timestamp('1954-07-01 00:00:00+0000', tz='UTC'),
#  Timestamp('1954-07-14 00:00:00+0000', tz='UTC'),
#  Timestamp('1954-07-31 00:00:00+0000', tz='UTC'),
#  Timestamp('1954-08-04 00:00:00+0000', tz='UTC'),
# ...

# %%
from datetime import datetime
from datetime import date
 
def rem_time(d):
    for i in len(data3):
        s = date(d.year,d.month)
        return s
 
d = time
print(rem_time(d))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [37], line 10
#       7         return s
#       9 d = time
# ---> 10 print(rem_time(d))
#
# Cell In [37], line 5, in rem_time(d)
#       4 def rem_time(d):
# ----> 5     for i in len(data3):
#       6         s = date(d.year,d.month)
#       7         return s
#
# TypeError: 'int' object is not iterable

# %%
data3['declaration_date_up'] = data3['declaration_date'].dt.strftime('%m/%d/%Y')
data3.disaster_closeout_date = pd.to_datetime(data3.disaster_closeout_date)
data3['disaster_closeout_date_up'] = data3['disaster_closeout_date'].dt.strftime('%m/%d/%Y')
data3.incident_begin_date = pd.to_datetime(data3.incident_begin_date)
data3['incident_begin_date_up'] = data3['incident_begin_date'].dt.strftime('%m/%d/%Y')
data3.incident_end_date = pd.to_datetime(data3.incident_end_date)
data3['incident_end_date_up'] = data3['incident_end_date'].dt.strftime('%m/%d/%Y')
data3.last_refresh = pd.to_datetime(data3.last_refresh)
data3['last_refresh_up'] = data3['last_refresh'].dt.strftime('%m/%d/%Y')
data3
# Out:
#       fema_declaration_string  disaster_number state declaration_type  \
# 0                     DR-1-GA                1    GA               DR
# 1                     DR-2-TX                2    TX               DR
# 2                     DR-3-LA                3    LA               DR
# 3                     DR-4-MI                4    MI               DR
# 4                     DR-5-MT                5    MT               DR
# ...                       ...              ...   ...              ...
# 55447              EM-3586-NC             3586    NC               EM
# 55448              EM-3586-NC             3586    NC               EM
# 55449              DR-4676-IL             4676    IL               DR
# 55450              FM-5456-WA             5456    WA               FM
# 55451              FM-5456-WA             5456    WA               FM
#
#                declaration_date  fy_declared incident_type  \
# 0     1953-05-02 00:00:00+00:00         1953       Tornado
# ...

# %%
data4 = data3.drop(['declaration_date','incident_begin_date','incident_end_date','disaster_closeout_date','last_refresh'],axis=1)
data4
# Out:
#       fema_declaration_string  disaster_number state declaration_type  \
# 0                     DR-1-GA                1    GA               DR
# 1                     DR-2-TX                2    TX               DR
# 2                     DR-3-LA                3    LA               DR
# 3                     DR-4-MI                4    MI               DR
# 4                     DR-5-MT                5    MT               DR
# ...                       ...              ...   ...              ...
# 55447              EM-3586-NC             3586    NC               EM
# 55448              EM-3586-NC             3586    NC               EM
# 55449              DR-4676-IL             4676    IL               DR
# 55450              FM-5456-WA             5456    WA               FM
# 55451              FM-5456-WA             5456    WA               FM
#
#        fy_declared incident_type          declaration_title  \
# 0             1953       Tornado                    Tornado
# ...

# %%
data4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 55452 entries, 0 to 55451
# Data columns (total 25 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   fema_declaration_string     55452 non-null  object
#  1   disaster_number             55452 non-null  int64
#  2   state                       55452 non-null  object
#  3   declaration_type            55452 non-null  object
#  4   fy_declared                 55452 non-null  int64
#  5   incident_type               55452 non-null  object
#  6   declaration_title           55452 non-null  object
#  7   ih_program_declared         55452 non-null  int64
#  8   ia_program_declared         55452 non-null  int64
#  9   pa_program_declared         55452 non-null  int64
#  10  hm_program_declared         55452 non-null  int64
#  11  fips                        55452 non-null  int64
#  12  place_code                  55452 non-null  int64
# ...

# %%
data4[['declaration_date_up','incident_begin_date_up','incident_end_date_up','disaster_closeout_date_up','last_refresh_up']] = data4[['declaration_date_up','incident_begin_date_up','incident_end_date_up','disaster_closeout_date_up','last_refresh_up']].apply(pd.to_datetime, errors='coerce')
data4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 55452 entries, 0 to 55451
# Data columns (total 25 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   fema_declaration_string     55452 non-null  object
#  1   disaster_number             55452 non-null  int64
#  2   state                       55452 non-null  object
#  3   declaration_type            55452 non-null  object
#  4   fy_declared                 55452 non-null  int64
#  5   incident_type               55452 non-null  object
#  6   declaration_title           55452 non-null  object
#  7   ih_program_declared         55452 non-null  int64
#  8   ia_program_declared         55452 non-null  int64
#  9   pa_program_declared         55452 non-null  int64
#  10  hm_program_declared         55452 non-null  int64
#  11  fips                        55452 non-null  int64
#  12  place_code                  55452 non-null  int64
# ...

# %%
decalarations_table = data4[['fema_declaration_string','disaster_number','declaration_type','declaration_date_up','fy_declared','declaration_title','disaster_closeout_date_up','fips','designated_area','declaration_request_number','id','last_refresh_up','state_mergekey']]
decalarations_table
# Out:
#       fema_declaration_string  disaster_number declaration_type  \
# 0                     DR-1-GA                1               DR
# 1                     DR-2-TX                2               DR
# 2                     DR-3-LA                3               DR
# 3                     DR-4-MI                4               DR
# 4                     DR-5-MT                5               DR
# ...                       ...              ...              ...
# 55447              EM-3586-NC             3586               EM
# 55448              EM-3586-NC             3586               EM
# 55449              DR-4676-IL             4676               DR
# 55450              FM-5456-WA             5456               FM
# 55451              FM-5456-WA             5456               FM
#
#       declaration_date_up  fy_declared          declaration_title  \
# 0              1953-05-02         1953                    Tornado
# ...

# %%
decalarations_table.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 55452 entries, 0 to 55451
# Data columns (total 13 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   fema_declaration_string     55452 non-null  object
#  1   disaster_number             55452 non-null  int64
#  2   declaration_type            55452 non-null  object
#  3   declaration_date_up         55452 non-null  datetime64[ns]
#  4   fy_declared                 55452 non-null  int64
#  5   declaration_title           55452 non-null  object
#  6   disaster_closeout_date_up   44699 non-null  datetime64[ns]
#  7   fips                        55452 non-null  int64
#  8   designated_area             55452 non-null  object
#  9   declaration_request_number  55452 non-null  int64
#  10  id                          55452 non-null  object
#  11  last_refresh_up             55452 non-null  datetime64[ns]
# ...

# %%
decalarations_table.isnull().sum()
# Out:
# fema_declaration_string           0
# disaster_number                   0
# declaration_type                  0
# declaration_date_up               0
# fy_declared                       0
# declaration_title                 0
# disaster_closeout_date_up     10753
# fips                              0
# designated_area                   0
# declaration_request_number        0
# id                                0
# last_refresh_up                   0
# state_mergekey                  205
# dtype: int64

# %%
decalarations_table.to_csv('Dec_Table.csv')

# %%
incidents_table = data4[['incident_type','incident_begin_date_up','incident_end_date_up','place_code','hash']]
incidents_table
# Out:
#       incident_type incident_begin_date_up incident_end_date_up  place_code  \
# 0           Tornado             1953-05-02           1953-05-02           0
# 1           Tornado             1953-05-15           1953-05-15           0
# 2             Flood             1953-05-29           1953-05-29           0
# 3           Tornado             1953-06-02           1953-06-02           0
# 4             Flood             1953-06-06           1953-06-06           0
# ...             ...                    ...                  ...         ...
# 55447     Hurricane             2022-09-28                  NaT       99147
# 55448     Hurricane             2022-09-28                  NaT       99173
# 55449         Flood             2022-07-25           2022-07-28       99163
# 55450          Fire             2022-10-09                  NaT       99011
# 55451          Fire             2022-10-09                  NaT       99059
#
#                                            hash
# ...

# %%
incidents_table.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 55452 entries, 0 to 55451
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   incident_type           55452 non-null  object
#  1   incident_begin_date_up  55452 non-null  datetime64[ns]
#  2   incident_end_date_up    54644 non-null  datetime64[ns]
#  3   place_code              55452 non-null  int64
#  4   hash                    55452 non-null  object
# dtypes: datetime64[ns](2), int64(1), object(2)
# memory usage: 2.5+ MB

# %%
incidents_table.isnull().sum()
# Out:
# incident_type               0
# incident_begin_date_up      0
# incident_end_date_up      808
# place_code                  0
# hash                        0
# dtype: int64

# %%
incidents_table.to_csv('Inc_Table.csv')

# %%
program_table = data4[['ih_program_declared','ia_program_declared','pa_program_declared','hm_program_declared']]
program_table
# Out:
#        ih_program_declared  ia_program_declared  pa_program_declared  \
# 0                        0                    1                    1
# 1                        0                    1                    1
# 2                        0                    1                    1
# 3                        0                    1                    1
# 4                        0                    1                    1
# ...                    ...                  ...                  ...
# 55447                    0                    0                    1
# 55448                    0                    0                    1
# 55449                    1                    0                    0
# 55450                    0                    0                    1
# 55451                    0                    0                    1
#
#        hm_program_declared
# 0                        1
# 1                        1
# 2                        1
# ...

# %%
program_table.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 55452 entries, 0 to 55451
# Data columns (total 4 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ih_program_declared  55452 non-null  int64
#  1   ia_program_declared  55452 non-null  int64
#  2   pa_program_declared  55452 non-null  int64
#  3   hm_program_declared  55452 non-null  int64
# dtypes: int64(4)
# memory usage: 2.1 MB

# %%
program_table.isnull().sum()
# Out:
# ih_program_declared    0
# ia_program_declared    0
# pa_program_declared    0
# hm_program_declared    0
# dtype: int64

# %%
program_table.to_csv('Prog_Table.csv')

# %%
state_table = state_data
state_table
# Out:
#                    State Standard state_mergekey
# 0                Alabama     Ala.             AL
# 1                 Alaska   Alaska             AK
# 2                Arizona    Ariz.             AZ
# 3               Arkansas     Ark.             AR
# 4             California   Calif.             CA
# 5             Canal Zone     C.Z.             CZ
# 6               Colorado    Colo.             CO
# 7            Connecticut    Conn.             CT
# 8               Delaware     Del.             DE
# 9   District of Columbia     D.C.             DC
# 10               Florida     Fla.             FL
# 11               Georgia      Ga.             GA
# 12                  Guam     Guam             GU
# 13                Hawaii   Hawaii             HI
# 14                 Idaho    Idaho             ID
# 15              Illinois     Ill.             IL
# 16               Indiana     Ind.             IN
# 17                  Iowa     Iowa             IA
# ...

# %%
state_table.to_csv('State_Table.csv')

# %%
temp_data = pd.read_csv('Temp_Table_redone.csv')
temp_data = pd.DataFrame(temp_data)
temp_data
# Out:
#       Unnamed: 0  Year    State  Avg_Temperature State_ID
# 0              0  1953  Alabama           17.773       AL
# 1              1  1954  Alabama           17.994       AL
# 2              2  1955  Alabama           17.612       AL
# 3              3  1956  Alabama           17.718       AL
# 4              4  1957  Alabama           17.903       AL
# ...          ...   ...      ...              ...      ...
# 3055        3055  2008  Wyoming            5.067       WY
# 3056        3056  2009  Wyoming            5.200       WY
# 3057        3057  2010  Wyoming            5.756       WY
# 3058        3058  2011  Wyoming            5.312       WY
# 3059        3059  2012  Wyoming            7.306       WY
#
# [3060 rows x 5 columns]

# %%
temp_data.columns =['ID','Year', 'State', 'Avg_Temperature','State_ID']
temp_data
# Out:
#         ID  Year    State  Avg_Temperature State_ID
# 0        0  1953  Alabama           17.773       AL
# 1        1  1954  Alabama           17.994       AL
# 2        2  1955  Alabama           17.612       AL
# 3        3  1956  Alabama           17.718       AL
# 4        4  1957  Alabama           17.903       AL
# ...    ...   ...      ...              ...      ...
# 3055  3055  2008  Wyoming            5.067       WY
# 3056  3056  2009  Wyoming            5.200       WY
# 3057  3057  2010  Wyoming            5.756       WY
# 3058  3058  2011  Wyoming            5.312       WY
# 3059  3059  2012  Wyoming            7.306       WY
#
# [3060 rows x 5 columns]

# %%
temp_data1 = temp_data.iloc[: , 1:]
temp_data1
# Out:
#         State  Avg_Temperature State_ID
# 0     Alabama           17.773       AL
# 1     Alabama           17.994       AL
# 2     Alabama           17.612       AL
# 3     Alabama           17.718       AL
# 4     Alabama           17.903       AL
# ...       ...              ...      ...
# 3055  Wyoming            5.067       WY
# 3056  Wyoming            5.200       WY
# 3057  Wyoming            5.756       WY
# 3058  Wyoming            5.312       WY
# 3059  Wyoming            7.306       WY
#
# [3060 rows x 3 columns]

# %%
data5 = pd.merge(left=data3,right=temp_data,left_on="state",right_on="state_mergekey",how="left")
